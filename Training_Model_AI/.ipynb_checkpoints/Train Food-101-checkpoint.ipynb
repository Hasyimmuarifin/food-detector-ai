# %% [markdown]
# ## **📦 1. Install dependensi**

# %%
pip install tensorflow numpy matplotlib
# Out:
# Requirement already satisfied: tensorflow in d:\anaconda3\envs\kuliah-ai\lib\site-packages (2.19.0)
# Requirement already satisfied: numpy in d:\anaconda3\envs\kuliah-ai\lib\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in d:\anaconda3\envs\kuliah-ai\lib\site-packages (3.10.1)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\advan\appdata\roaming\python\python310\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\advan\appdata\roaming\python\python310\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\advan\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\advan\appdata\roaming\python\python310\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (1.73.0)
# Requirement already satisfied: tensorboard~=2.19.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\advan\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\advan\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\advan\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\advan\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\advan\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\advan\appdata\roaming\python\python310\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\advan\appdata\roaming\python\python310\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\envs\kuliah-ai\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## **🧾 2. Load File Split dan Kelas**

# %%
import os
import tensorflow as tf

DATASET_DIR = "food-101"
IMAGES_DIR = os.path.join(DATASET_DIR, "images")
META_DIR = os.path.join(DATASET_DIR, "meta")

# Load daftar kelas
with open(os.path.join(META_DIR, "classes.txt")) as f:
    class_names = [line.strip() for line in f.readlines()]
class_to_index = {name: idx for idx, name in enumerate(class_names)}

# Load daftar gambar untuk training dan testing
def load_split(split):
    with open(os.path.join(META_DIR, f"{split}.txt")) as f:
        lines = [line.strip() for line in f.readlines()]
    image_paths = [os.path.join(IMAGES_DIR, f"{line}.jpg") for line in lines]
    labels = [class_to_index[line.split("/")[0]] for line in lines]
    return image_paths, labels

train_paths, train_labels = load_split("train")
test_paths, test_labels = load_split("test")

# %% [markdown]
# ## **🖼️ 3. Preprocessing dan Dataset Pipeline**

# %%
IMG_SIZE = 224
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

def preprocess(path, label):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = image / 255.0
    return image, tf.one_hot(label, depth=len(class_names))

train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
train_ds = train_ds.map(preprocess, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.shuffle(1000).batch(BATCH_SIZE).prefetch(AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((test_paths, test_labels))
test_ds = test_ds.map(preprocess, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %% [markdown]
# ## **🔧 4. Bangun dan Latih Model**

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False

x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(512, activation='relu')(x)
output = tf.keras.layers.Dense(len(class_names), activation='softmax')(x)

model = tf.keras.models.Model(inputs=base_model.input, outputs=output)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_ds, epochs=10, validation_data=test_ds)
# Out:
# Epoch 1/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 314s 351ms/step - accuracy: 0.7811 - loss: 0.9576 - val_accuracy: 0.1381 - val_loss: 7.1902
# Epoch 2/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 295s 339ms/step - accuracy: 0.8224 - loss: 0.6634 - val_accuracy: 0.1981 - val_loss: 5.4213
# Epoch 3/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 292s 336ms/step - accuracy: 0.8790 - loss: 0.3914 - val_accuracy: 0.2493 - val_loss: 4.9751
# Epoch 4/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 292s 336ms/step - accuracy: 0.8928 - loss: 0.3421 - val_accuracy: 0.2505 - val_loss: 5.2696
# Epoch 5/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 290s 334ms/step - accuracy: 0.9064 - loss: 0.3128 - val_accuracy: 0.2401 - val_loss: 6.0417
# Epoch 6/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 292s 336ms/step - accuracy: 0.9154 - loss: 0.2913 - val_accuracy: 0.2785 - val_loss: 5.2903
# Epoch 7/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 291s 335ms/step - accuracy: 0.9221 - loss: 0.2647 - val_accuracy: 0.3443 - val_loss: 4.2306
# Epoch 8/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 291s 334ms/step - accuracy: 0.9256 - loss: 0.2408 - val_accuracy: 0.3239 - val_loss: 5.0071
# Epoch 9/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 295s 340ms/step - accuracy: 0.9385 - loss: 0.1956 - val_accuracy: 0.3378 - val_loss: 5.2018
# Epoch 10/10
# 868/868 ━━━━━━━━━━━━━━━━━━━━ 291s 335ms/step - accuracy: 0.9437 - loss: 0.1811 - val_accuracy: 0.3534 - val_loss: 4.8872

# %% [markdown]
# ## **📈 5. Langkah-langkah Evaluasi Model di JupyterLab**

# %% [markdown]
# ####  Evaluasi model menggunakan confusion_matrix dari sklearn, classification_report untuk precision, recall, dan F1-score

# %% [markdown]
# ######  Menambahkan evaluasi seperti Confusion Matrix, Classification Report, dan F1 Score akan sangat membantu dalam mengetahui kelas mana yang sulit dikenali dan seberapa baik model bekerja secara menyeluruh.

# %% [markdown]
# #### **🧾 1. Import Library Tambahan**

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### **🗃️ 2. Prediksi pada Test Dataset**

# %%
# Ambil semua gambar dan label dari test_ds
y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %% [markdown]
# ###### Kita harus menggabungkan hasil prediksi dan label asli:

# %% [markdown]
# #### **📊 3. Tampilkan Confusion Matrix**

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(15, 12))
sns.heatmap(cm, xticklabels=class_names, yticklabels=class_names, 
            annot=False, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# #### **🧠 4. Tampilkan Classification Report**

# %%
report = classification_report(y_true, y_pred, target_names=class_names)
print(report)
# Out:
#                       precision    recall  f1-score   support
#
#             beignets       0.85      0.60      0.70       250
#             bibimbap       0.97      0.26      0.41       250
#        chicken_wings       1.00      0.13      0.23       250
#              churros       0.97      0.27      0.42       250
#         clam_chowder       1.00      0.26      0.41       250
#        club_sandwich       1.00      0.01      0.02       250
#            cup_cakes       0.85      0.07      0.13       250
#         deviled_eggs       1.00      0.09      0.16       250
#               donuts       1.00      0.09      0.16       250
#            dumplings       0.99      0.68      0.81       250
#              edamame       0.99      0.83      0.90       250
#            escargots       1.00      0.12      0.21       250
#         french_fries       0.88      0.14      0.25       250
#                gyoza       1.00      0.01      0.02       250
#            hamburger       1.00      0.04      0.08       250
#              hot_dog       1.00      0.08      0.15       250
#            ice_cream       1.00      0.00      0.01       250
#              lasagna       0.86      0.05      0.09       250
#  macaroni_and_cheese       0.85      0.09      0.16       250
#             macarons       1.00      0.26      0.41       250
#              oysters       0.91      0.24      0.38       250
#             pad_thai       1.00      0.00      0.01       250
#             pancakes       0.76      0.06      0.12       250
#                  pho       0.99      0.64      0.78       250
#                pizza       0.81      0.62      0.70       250
#              poutine       0.32      0.24      0.27       250
#      red_velvet_cake       0.37      0.14      0.20       250
#              sashimi       0.88      0.18      0.30       250
#        seaweed_salad       0.75      0.71      0.73       250
#  spaghetti_bolognese       0.52      0.59      0.55       250
#  spaghetti_carbonara       0.55      0.90      0.68       250
# strawberry_shortcake       0.45      0.49      0.47       250
#                sushi       0.22      0.76      0.34       250
#                tacos       0.22      0.70      0.33       250
#             takoyaki       0.16      0.88      0.28       250
#             tiramisu       0.19      0.90      0.31       250
#              waffles       0.12      0.94      0.21       250
#
#             accuracy                           0.35      9250
#            macro avg       0.77      0.35      0.34      9250
#         weighted avg       0.77      0.35      0.34      9250

# %% [markdown]
# #### **📦 5. (Opsional) Simpan Hasil Evaluasi ke File .txt**

# %%
with open("evaluation_report.txt", "w") as f:
    f.write(report)

# %% [markdown]
# ## **💿 7. Visualisasi Akurasi dan Loss**

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy